# %% [markdown]
# <a href="https://colab.research.google.com/github/sohansputhran/Algorithmic-Redistricting/blob/main/scatter_plot_time_trend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 972kB 5.5MB/s
# ...
#      |████████████████████████████████| 14.8MB 321kB/s
# ...
#      |████████████████████████████████| 6.5MB 40.2MB/s
# ...

# %%
# !pip install pyshp
# Out:
# ...
#      |████████████████████████████████| 225kB 5.2MB/s
# ...
#   Created wheel for pyshp: filename=pyshp-2.1.3-cp37-none-any.whl size=37264 sha256=1a5b04bcb39ed92744d3157cd8aec955b208e32486f562b07c392a9a3eb8d6ca
#   Stored in directory: /root/.cache/pip/wheels/76/2b/d4/53e6b9a0fb0a9f9f29664cf82605af8bc81d5ab44d987896dd
# Successfully built pyshp
# ...

# %%
import geopandas as gp

# %%
import shapefile as shp

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive
#drive.mount("/content/gdrive")

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# import os
# os.chdir("/content/drive/my-drive")
# !ls

# %%
#Executing the following two lines of code will import the data into Colab:

import pandas as pd
sf = shp.Reader('/content/gdrive/My Drive/Colab Notebooks/IA_counties/IA_counties.shp')

# %%
# import os
# os.chdir("/content/drive/")
# !ls

# %%
# ! ls /content/drive/My\ Drive/data/

# %%
#sf = shp.Reader("IA_counties.shp")

# %%
plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
import numpy as np

# %%
IA = gp.read_file('/content/gdrive/My Drive/Colab Notebooks/IA_counties/IA_counties.shp')

# %%
# Fixing random state for reproducibility
#np.random.seed(19680801)

# %%
#N = 50
# # x = np.random.rand(N)
# # y = np.random.rand(N)
#area = 50  # 0 to 15 point radii
#colors = np.random.rand(N)

# %%
# plt.scatter('IA[NH_WHITE]', 'IA[TOTVOT04]')
# #plt.scatter('IA[NH_WHITE]','IA[NH_BLACK]')
# plt.show()

# %% [markdown]
# 2000 Democratic presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES00D"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES00D"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES00D"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES00D"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES00D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES00D"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES00D"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES00D"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES00D"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES00D"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES00D"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES00D"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES00D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES00D"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES00D"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Democratic presidential candidate")
plt.show()

# %% [markdown]
# 2000 Republican presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES00R"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES00R"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES00R"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES00R"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES00R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES00R"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES00R"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES00R"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES00R"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES00R"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES00R"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES00R"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES00R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES00R"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES00R"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Republican presidential candidate")
plt.show()

# %% [markdown]
# 2000 Green Party presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES00G"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES00G"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES00G"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES00G"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES00G"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES00G"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES00G"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES00G"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES00G"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES00G"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES00G"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES00G"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES00G"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES00G"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES00G"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2000 Green Party presidential candidate")
plt.show()

# %% [markdown]
# 2000 other presidential candidates

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES00OTH"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES00OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES00OTH"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES00OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES00OTH"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2000 other presidential candidates")
plt.show()

# %% [markdown]
# 2004 Democratic presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES04D"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES04D"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES04D"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES04D"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES04D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES04D"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES04D"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES04D"]
)

ax.set_xlabel("Hispanic populationn")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES04D"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES04D"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES04D"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES04D"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES04D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES04D"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES04D"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Democratic presidential candidate")
plt.show()

# %% [markdown]
# 2004 Republican presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES04R"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES04R"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES04R"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES04R"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES04R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES04R"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES04R"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES04R"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES04R"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES04R"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES04R"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES04R"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES04R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES04R"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES04R"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2004 Republican presidential candidate")
plt.show()

# %% [markdown]
# 2004 other presidential candidates

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES04OTH"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES04OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES04OTH"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES04OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES04OTH"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2004 other presidential candidates")
plt.show()

# %% [markdown]
# 2008 Democratic presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES08D"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES08D"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES08D"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES08D"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES08D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES08D"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES08D"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES08D"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES08D"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES08D"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES08D"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES08D"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES08D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES08D"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES08D"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Democratic presidential candidate")
plt.show()

# %% [markdown]
#  2008 Republican presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES08R"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES08R"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES08R"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES08R"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES08R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES08R"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES08R"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES08R"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES08R"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES08R"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES08R"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES08R"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES08R"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES08R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES08R"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES08R"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2008 Republican presidential candidate")
plt.show()

# %% [markdown]
# *2008* other presidential candidates

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES08OTH"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES08OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES08OTH"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES08OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %% [markdown]
# 2012 Democratic presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES12D"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES12D"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES12D"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES12D"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES12D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES12D"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES12D"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES12D"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES12D"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES12D"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES12D"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES12D"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES12D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES12D"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES12D"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()

# %% [markdown]
# 2012 Republican presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES12R"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES12R"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES12R"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES12R"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES12R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES12R"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES12R"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES12R"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES12R"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES12R"]
)

ax.set_xlabel("Black, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES12R"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES12R"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES12R"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES12R"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES12R"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2012 Republican presidential candidate")
plt.show()

# %% [markdown]
# 2012 other presidential candidates

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES12OTH"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES12OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_2MORE"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Two or more races, non-hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["HISP"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Hispanic population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_WHITE"],
    IA["PRES12OTH"]
)

ax.set_xlabel("White, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_BLACK"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Black, hispanic, populationn")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_AMIN"],
    IA["PRES12OTH"]
)

ax.set_xlabel("American Indian and Alaska Native, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_ASIAN"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Asian, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["N_NHPI"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_OTHER"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Other race, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["H_2MORE"],
    IA["PRES12OTH"]
)

ax.set_xlabel("Two or more races, hispanic, population")
ax.set_ylabel("Number of votes for 2012 other presidential candidates")
plt.show()

# %% [markdown]
# 2016 Democratic presidential candidate

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES16D"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_BLACK"],
    IA["PRES16D"]
)

ax.set_xlabel("Black, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_AMIN"],
    IA["PRES16D"]
)

ax.set_xlabel("American Indian and Alaska Native, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_ASIAN"],
    IA["PRES16D"]
)

ax.set_xlabel("Asian, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_NHPI"],
    IA["PRES16D"]
)

ax.set_xlabel("Native Hawaiian and Pacific Islander, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 Democratic presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES16R"]
)

ax.set_xlabel("White, non-hispanic, population")
ax.set_ylabel("Number of votes for 2016 republican presidential candidate")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_OTHER"],
    IA["PRES08OTH"]
)

ax.set_xlabel("Other race, non-hispanic, population")
ax.set_ylabel("Number of votes for 2008 other presidential candidates")
plt.show()

# %%
fig,ax = plt.subplots()

my_scatter_plot = ax.scatter(
    IA["NH_WHITE"],
    IA["PRES12D"]
)

ax.set_xlabel("White, non-hispanic, population in 2010 Census")
ax.set_ylabel("Number of votes for 2012 Democratic presidential candidate")
plt.show()
