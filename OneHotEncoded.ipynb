# %% [markdown]
# <a href="https://colab.research.google.com/github/sohansputhran/Algorithmic-Redistricting/blob/main/OneHotEncoded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8a5d7559-4be2-42b1-8304-c4ab983c1c0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a5d7559-4be2-42b1-8304-c4ab983c1c0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IA_counties.csv to IA_counties.csv
# ...

# %%
import pandas as pd
df = pd.read_csv('IA_counties.csv')
df
# Out:
#             X          Y  STATEFP10  ...  PRES16R  PRES16OTH CD
# 0  -92.999001  42.035801         19  ...     9146       1182  1
# 1  -92.066966  42.080299         19  ...     8232        934  1
# 2  -95.150846  43.082520         19  ...     5877        491  4
# 3  -95.325464  41.684636         19  ...     4362        346  4
# 4  -91.352586  42.862146         19  ...     5317        575  1
# ..        ...        ...        ...  ...      ...        ... ..
# 94 -91.538382  40.594834         19  ...     8803       1133  2
# 95 -93.465211  42.035540         19  ...    19458       5500  4
# 96 -92.768104  42.382062         19  ...     4527        489  4
# 97 -95.550817  41.333039         19  ...    24447       2878  3
# 98 -92.317235  43.357300         19  ...     2611        271  1
#
# [99 rows x 58 columns]

# %%
df = df.drop(['NAMELSAD10'], axis=1)
df
# Out:
#             X          Y  STATEFP10  ...  PRES16R  PRES16OTH CD
# 0  -92.999001  42.035801         19  ...     9146       1182  1
# 1  -92.066966  42.080299         19  ...     8232        934  1
# 2  -95.150846  43.082520         19  ...     5877        491  4
# 3  -95.325464  41.684636         19  ...     4362        346  4
# 4  -91.352586  42.862146         19  ...     5317        575  1
# ..        ...        ...        ...  ...      ...        ... ..
# 94 -91.538382  40.594834         19  ...     8803       1133  2
# 95 -93.465211  42.035540         19  ...    19458       5500  4
# 96 -92.768104  42.382062         19  ...     4527        489  4
# 97 -95.550817  41.333039         19  ...    24447       2878  3
# 98 -92.317235  43.357300         19  ...     2611        271  1
#
# [99 rows x 57 columns]

# %%
df = pd.concat([df,pd.get_dummies(df['NAME10'], prefix='county')],axis=1)
df
# Out:
#             X          Y  ...  county_Worth  county_Wright
# 0  -92.999001  42.035801  ...             0              0
# 1  -92.066966  42.080299  ...             0              0
# 2  -95.150846  43.082520  ...             0              0
# 3  -95.325464  41.684636  ...             0              0
# 4  -91.352586  42.862146  ...             0              0
# ..        ...        ...  ...           ...            ...
# 94 -91.538382  40.594834  ...             0              0
# 95 -93.465211  42.035540  ...             0              0
# 96 -92.768104  42.382062  ...             0              0
# 97 -95.550817  41.333039  ...             0              0
# 98 -92.317235  43.357300  ...             0              0
#
# [99 rows x 156 columns]

# %%
df = df.drop(['NAME10'], axis=1)
df
# Out:
#             X          Y  ...  county_Worth  county_Wright
# 0  -92.999001  42.035801  ...             0              0
# 1  -92.066966  42.080299  ...             0              0
# 2  -95.150846  43.082520  ...             0              0
# 3  -95.325464  41.684636  ...             0              0
# 4  -91.352586  42.862146  ...             0              0
# ..        ...        ...  ...           ...            ...
# 94 -91.538382  40.594834  ...             0              0
# 95 -93.465211  42.035540  ...             0              0
# 96 -92.768104  42.382062  ...             0              0
# 97 -95.550817  41.333039  ...             0              0
# 98 -92.317235  43.357300  ...             0              0
#
# [99 rows x 155 columns]
